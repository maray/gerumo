# %%
import tables

# %%
hdf5_filepath = "/home/sven-klein-plarre/Documentos/Universidad/Magister/Tesis/Dataset CTAO Monte Carlo Simulations - Eventlist on DL2 prod5/7298569/gamma-diffuse_with_images_00.dl2.h5"
hdf5_file = tables.open_file(hdf5_filepath, "r")

# %%
r = hdf5_file.root
test_dl1 = r["dl1"]
test_dl2 = r["dl2"]

# %%
test_dl1._f_get_child
# Out:
# <bound method Group._f_get_child of /dl1 (Group) ''
#   children := ['event' (Group), 'monitoring' (Group), 'service' (Group)]>

# %%
test_dl2._f_get_child
# Out:
# <bound method Group._f_get_child of /dl2 (Group) ''
#   children := ['event' (Group), 'service' (Group)]>

# %%
dl1_event = test_dl1["event"]
dl1_monitoring = test_dl1["monitoring"]
dl1_service = test_dl1["service"]
dl2_event = test_dl2["event"]
dl2_service = test_dl2["service"]

# %%
# Out:
# /home/sven-klein-plarre/anaconda3/envs/gerumo/lib/python3.7/site-packages/tables/group.py:1164: UserWarning: problems loading leaf ``/dl2/event/telescope/impact/HillasReconstructor/tel_007``::
#
#   trying to register a node with an existing key: ``/dl2/event/telescope/impact/HillasReconstructor/tel_007``
#
# The leaf will become an ``UnImplemented`` node.
#   % (self._g_join(childname), exc))
# <bound method File.close of File(filename=/home/sven-klein-plarre/Documentos/Universidad/Magister/Tesis/Dataset CTAO Monte Carlo Simulations - Eventlist on DL2 prod5/7298569/gamma-diffuse_with_images_00.dl2.h5, title='', mode='r', root_uep='/', filters=Filters(complevel=0, shuffle=False, bitshuffle=False, fletcher32=False, least_significant_digit=None))
# / (RootGroup) ''
# /configuration (Group) ''
# /dl1 (Group) ''
# /dl2 (Group) ''
# /simulation (Group) ''
# /simulation/event (Group) ''
# /simulation/service (Group) ''
# /simulation/service/shower_distribution (Table(50,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of SimulatedShowerDistribution'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "hist_id": Int64Col(shape=(), dflt=0, pos=1),
#   "n_entries": Int64Col(shape=(), dflt=0, pos=2),
#   "bins_energy": Float64Col(shape=(121,), dflt=0.0, pos=3),
#   "bins_core_dist": Float64Col(shape=(201,), dflt=0.0, pos=4),
#   "histogram": Float32Col(shape=(120, 200), dflt=0.0, pos=5)}
#   byteorder := 'little'
#   chunkshape := (2,)
# /simulation/event/subarray (Group) ''
# /simulation/event/subarray/shower (Table(33922,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of EventIndexContainer,SimulatedShowerContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "true_energy": Float64Col(shape=(), dflt=0.0, pos=2),
#   "true_alt": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_az": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_core_x": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_core_y": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_h_first_int": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_x_max": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_shower_primary_id": Int64Col(shape=(), dflt=0, pos=9)}
#   byteorder := 'little'
#   chunkshape := (862,)
# /simulation/event/telescope (Group) ''
# /simulation/event/telescope/images (Group) ''
# /simulation/event/telescope/images/tel_001 (Table(5987,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,SimulatedCameraContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_image_sum": Int32Col(shape=(), dflt=0, pos=3),
#   "true_image": Int32Col(shape=(1855,), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (17,)
# /simulation/event/telescope/images/tel_002 (Table(6543,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,SimulatedCameraContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_image_sum": Int32Col(shape=(), dflt=0, pos=3),
#   "true_image": Int32Col(shape=(1855,), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (17,)
# /simulation/event/telescope/images/tel_003 (Table(6079,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,SimulatedCameraContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_image_sum": Int32Col(shape=(), dflt=0, pos=3),
#   "true_image": Int32Col(shape=(1855,), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (17,)
# /simulation/event/telescope/images/tel_004 (Table(6512,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,SimulatedCameraContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_image_sum": Int32Col(shape=(), dflt=0, pos=3),
#   "true_image": Int32Col(shape=(1855,), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (17,)
# /simulation/event/telescope/images/tel_005 (Table(7519,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,SimulatedCameraContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_image_sum": Int32Col(shape=(), dflt=0, pos=3),
#   "true_image": Int32Col(shape=(1855,), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (17,)
# /simulation/event/telescope/images/tel_006 (Table(7547,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,SimulatedCameraContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_image_sum": Int32Col(shape=(), dflt=0, pos=3),
#   "true_image": Int32Col(shape=(1855,), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (17,)
# /simulation/event/telescope/images/tel_007 (Table(6983,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,SimulatedCameraContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_image_sum": Int32Col(shape=(), dflt=0, pos=3),
#   "true_image": Int32Col(shape=(1855,), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (17,)
# /simulation/event/telescope/images/tel_008 (Table(7697,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,SimulatedCameraContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_image_sum": Int32Col(shape=(), dflt=0, pos=3),
#   "true_image": Int32Col(shape=(1855,), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (17,)
# /simulation/event/telescope/images/tel_009 (Table(7610,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,SimulatedCameraContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_image_sum": Int32Col(shape=(), dflt=0, pos=3),
#   "true_image": Int32Col(shape=(1855,), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (17,)
# /simulation/event/telescope/images/tel_010 (Table(7570,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,SimulatedCameraContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_image_sum": Int32Col(shape=(), dflt=0, pos=3),
#   "true_image": Int32Col(shape=(1855,), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (17,)
# /simulation/event/telescope/images/tel_011 (Table(7437,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,SimulatedCameraContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_image_sum": Int32Col(shape=(), dflt=0, pos=3),
#   "true_image": Int32Col(shape=(1855,), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (17,)
# /simulation/event/telescope/images/tel_019 (Table(7680,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,SimulatedCameraContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_image_sum": Int32Col(shape=(), dflt=0, pos=3),
#   "true_image": Int32Col(shape=(1855,), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (17,)
# /simulation/event/telescope/images/tel_035 (Table(7639,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,SimulatedCameraContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_image_sum": Int32Col(shape=(), dflt=0, pos=3),
#   "true_image": Int32Col(shape=(1855,), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (17,)
# /simulation/event/telescope/impact (Group) ''
# /simulation/event/telescope/impact/tel_001 (Table(5987,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeImpactParameterContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_impact_distance": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_impact_distance_uncert": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (2184,)
# /simulation/event/telescope/impact/tel_002 (Table(6543,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeImpactParameterContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_impact_distance": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_impact_distance_uncert": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (2184,)
# /simulation/event/telescope/impact/tel_003 (Table(6079,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeImpactParameterContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_impact_distance": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_impact_distance_uncert": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (2184,)
# /simulation/event/telescope/impact/tel_004 (Table(6512,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeImpactParameterContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_impact_distance": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_impact_distance_uncert": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (2184,)
# /simulation/event/telescope/impact/tel_005 (Table(7519,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeImpactParameterContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_impact_distance": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_impact_distance_uncert": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (2184,)
# /simulation/event/telescope/impact/tel_006 (Table(7547,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeImpactParameterContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_impact_distance": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_impact_distance_uncert": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (2184,)
# /simulation/event/telescope/impact/tel_007 (Table(6983,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeImpactParameterContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_impact_distance": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_impact_distance_uncert": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (2184,)
# /simulation/event/telescope/impact/tel_008 (Table(7697,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeImpactParameterContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_impact_distance": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_impact_distance_uncert": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (2184,)
# /simulation/event/telescope/impact/tel_009 (Table(7610,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeImpactParameterContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_impact_distance": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_impact_distance_uncert": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (2184,)
# /simulation/event/telescope/impact/tel_010 (Table(7570,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeImpactParameterContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_impact_distance": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_impact_distance_uncert": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (2184,)
# /simulation/event/telescope/impact/tel_011 (Table(7437,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeImpactParameterContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_impact_distance": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_impact_distance_uncert": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (2184,)
# /simulation/event/telescope/impact/tel_019 (Table(7680,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeImpactParameterContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_impact_distance": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_impact_distance_uncert": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (2184,)
# /simulation/event/telescope/impact/tel_035 (Table(7639,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeImpactParameterContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_impact_distance": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_impact_distance_uncert": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (2184,)
# /simulation/event/telescope/parameters (Group) ''
# /simulation/event/telescope/parameters/tel_001 (Table(5987,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "true_hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "true_hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "true_hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "true_hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "true_hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "true_leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=15),
#   "true_leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=16),
#   "true_leakage_intensity_width_1": Float64Col(shape=(), dflt=0.0, pos=17),
#   "true_leakage_intensity_width_2": Float64Col(shape=(), dflt=0.0, pos=18),
#   "true_concentration_cog": Float64Col(shape=(), dflt=0.0, pos=19),
#   "true_concentration_core": Float64Col(shape=(), dflt=0.0, pos=20),
#   "true_concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=21),
#   "true_morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=22),
#   "true_morphology_n_islands": Int64Col(shape=(), dflt=0, pos=23),
#   "true_morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=24),
#   "true_morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=25),
#   "true_morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "true_intensity_max": Int32Col(shape=(), dflt=0, pos=27),
#   "true_intensity_min": Int32Col(shape=(), dflt=0, pos=28),
#   "true_intensity_mean": Float64Col(shape=(), dflt=0.0, pos=29),
#   "true_intensity_std": Float64Col(shape=(), dflt=0.0, pos=30),
#   "true_intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=31),
#   "true_intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=32)}
#   byteorder := 'little'
#   chunkshape := (266,)
# /simulation/event/telescope/parameters/tel_002 (Table(6543,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "true_hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "true_hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "true_hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "true_hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "true_hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "true_leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=15),
#   "true_leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=16),
#   "true_leakage_intensity_width_1": Float64Col(shape=(), dflt=0.0, pos=17),
#   "true_leakage_intensity_width_2": Float64Col(shape=(), dflt=0.0, pos=18),
#   "true_concentration_cog": Float64Col(shape=(), dflt=0.0, pos=19),
#   "true_concentration_core": Float64Col(shape=(), dflt=0.0, pos=20),
#   "true_concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=21),
#   "true_morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=22),
#   "true_morphology_n_islands": Int64Col(shape=(), dflt=0, pos=23),
#   "true_morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=24),
#   "true_morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=25),
#   "true_morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "true_intensity_max": Int32Col(shape=(), dflt=0, pos=27),
#   "true_intensity_min": Int32Col(shape=(), dflt=0, pos=28),
#   "true_intensity_mean": Float64Col(shape=(), dflt=0.0, pos=29),
#   "true_intensity_std": Float64Col(shape=(), dflt=0.0, pos=30),
#   "true_intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=31),
#   "true_intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=32)}
#   byteorder := 'little'
#   chunkshape := (266,)
# /simulation/event/telescope/parameters/tel_003 (Table(6079,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "true_hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "true_hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "true_hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "true_hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "true_hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "true_leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=15),
#   "true_leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=16),
#   "true_leakage_intensity_width_1": Float64Col(shape=(), dflt=0.0, pos=17),
#   "true_leakage_intensity_width_2": Float64Col(shape=(), dflt=0.0, pos=18),
#   "true_concentration_cog": Float64Col(shape=(), dflt=0.0, pos=19),
#   "true_concentration_core": Float64Col(shape=(), dflt=0.0, pos=20),
#   "true_concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=21),
#   "true_morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=22),
#   "true_morphology_n_islands": Int64Col(shape=(), dflt=0, pos=23),
#   "true_morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=24),
#   "true_morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=25),
#   "true_morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "true_intensity_max": Int32Col(shape=(), dflt=0, pos=27),
#   "true_intensity_min": Int32Col(shape=(), dflt=0, pos=28),
#   "true_intensity_mean": Float64Col(shape=(), dflt=0.0, pos=29),
#   "true_intensity_std": Float64Col(shape=(), dflt=0.0, pos=30),
#   "true_intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=31),
#   "true_intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=32)}
#   byteorder := 'little'
#   chunkshape := (266,)
# /simulation/event/telescope/parameters/tel_004 (Table(6512,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "true_hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "true_hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "true_hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "true_hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "true_hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "true_leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=15),
#   "true_leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=16),
#   "true_leakage_intensity_width_1": Float64Col(shape=(), dflt=0.0, pos=17),
#   "true_leakage_intensity_width_2": Float64Col(shape=(), dflt=0.0, pos=18),
#   "true_concentration_cog": Float64Col(shape=(), dflt=0.0, pos=19),
#   "true_concentration_core": Float64Col(shape=(), dflt=0.0, pos=20),
#   "true_concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=21),
#   "true_morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=22),
#   "true_morphology_n_islands": Int64Col(shape=(), dflt=0, pos=23),
#   "true_morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=24),
#   "true_morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=25),
#   "true_morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "true_intensity_max": Int32Col(shape=(), dflt=0, pos=27),
#   "true_intensity_min": Int32Col(shape=(), dflt=0, pos=28),
#   "true_intensity_mean": Float64Col(shape=(), dflt=0.0, pos=29),
#   "true_intensity_std": Float64Col(shape=(), dflt=0.0, pos=30),
#   "true_intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=31),
#   "true_intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=32)}
#   byteorder := 'little'
#   chunkshape := (266,)
# /simulation/event/telescope/parameters/tel_005 (Table(7519,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "true_hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "true_hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "true_hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "true_hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "true_hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "true_leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=15),
#   "true_leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=16),
#   "true_leakage_intensity_width_1": Float64Col(shape=(), dflt=0.0, pos=17),
#   "true_leakage_intensity_width_2": Float64Col(shape=(), dflt=0.0, pos=18),
#   "true_concentration_cog": Float64Col(shape=(), dflt=0.0, pos=19),
#   "true_concentration_core": Float64Col(shape=(), dflt=0.0, pos=20),
#   "true_concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=21),
#   "true_morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=22),
#   "true_morphology_n_islands": Int64Col(shape=(), dflt=0, pos=23),
#   "true_morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=24),
#   "true_morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=25),
#   "true_morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "true_intensity_max": Int32Col(shape=(), dflt=0, pos=27),
#   "true_intensity_min": Int32Col(shape=(), dflt=0, pos=28),
#   "true_intensity_mean": Float64Col(shape=(), dflt=0.0, pos=29),
#   "true_intensity_std": Float64Col(shape=(), dflt=0.0, pos=30),
#   "true_intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=31),
#   "true_intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=32)}
#   byteorder := 'little'
#   chunkshape := (266,)
# /simulation/event/telescope/parameters/tel_006 (Table(7547,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "true_hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "true_hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "true_hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "true_hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "true_hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "true_leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=15),
#   "true_leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=16),
#   "true_leakage_intensity_width_1": Float64Col(shape=(), dflt=0.0, pos=17),
#   "true_leakage_intensity_width_2": Float64Col(shape=(), dflt=0.0, pos=18),
#   "true_concentration_cog": Float64Col(shape=(), dflt=0.0, pos=19),
#   "true_concentration_core": Float64Col(shape=(), dflt=0.0, pos=20),
#   "true_concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=21),
#   "true_morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=22),
#   "true_morphology_n_islands": Int64Col(shape=(), dflt=0, pos=23),
#   "true_morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=24),
#   "true_morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=25),
#   "true_morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "true_intensity_max": Int32Col(shape=(), dflt=0, pos=27),
#   "true_intensity_min": Int32Col(shape=(), dflt=0, pos=28),
#   "true_intensity_mean": Float64Col(shape=(), dflt=0.0, pos=29),
#   "true_intensity_std": Float64Col(shape=(), dflt=0.0, pos=30),
#   "true_intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=31),
#   "true_intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=32)}
#   byteorder := 'little'
#   chunkshape := (266,)
# /simulation/event/telescope/parameters/tel_007 (Table(6983,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "true_hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "true_hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "true_hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "true_hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "true_hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "true_leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=15),
#   "true_leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=16),
#   "true_leakage_intensity_width_1": Float64Col(shape=(), dflt=0.0, pos=17),
#   "true_leakage_intensity_width_2": Float64Col(shape=(), dflt=0.0, pos=18),
#   "true_concentration_cog": Float64Col(shape=(), dflt=0.0, pos=19),
#   "true_concentration_core": Float64Col(shape=(), dflt=0.0, pos=20),
#   "true_concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=21),
#   "true_morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=22),
#   "true_morphology_n_islands": Int64Col(shape=(), dflt=0, pos=23),
#   "true_morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=24),
#   "true_morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=25),
#   "true_morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "true_intensity_max": Int32Col(shape=(), dflt=0, pos=27),
#   "true_intensity_min": Int32Col(shape=(), dflt=0, pos=28),
#   "true_intensity_mean": Float64Col(shape=(), dflt=0.0, pos=29),
#   "true_intensity_std": Float64Col(shape=(), dflt=0.0, pos=30),
#   "true_intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=31),
#   "true_intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=32)}
#   byteorder := 'little'
#   chunkshape := (266,)
# /simulation/event/telescope/parameters/tel_008 (Table(7697,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "true_hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "true_hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "true_hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "true_hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "true_hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "true_leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=15),
#   "true_leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=16),
#   "true_leakage_intensity_width_1": Float64Col(shape=(), dflt=0.0, pos=17),
#   "true_leakage_intensity_width_2": Float64Col(shape=(), dflt=0.0, pos=18),
#   "true_concentration_cog": Float64Col(shape=(), dflt=0.0, pos=19),
#   "true_concentration_core": Float64Col(shape=(), dflt=0.0, pos=20),
#   "true_concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=21),
#   "true_morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=22),
#   "true_morphology_n_islands": Int64Col(shape=(), dflt=0, pos=23),
#   "true_morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=24),
#   "true_morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=25),
#   "true_morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "true_intensity_max": Int32Col(shape=(), dflt=0, pos=27),
#   "true_intensity_min": Int32Col(shape=(), dflt=0, pos=28),
#   "true_intensity_mean": Float64Col(shape=(), dflt=0.0, pos=29),
#   "true_intensity_std": Float64Col(shape=(), dflt=0.0, pos=30),
#   "true_intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=31),
#   "true_intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=32)}
#   byteorder := 'little'
#   chunkshape := (266,)
# /simulation/event/telescope/parameters/tel_009 (Table(7610,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "true_hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "true_hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "true_hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "true_hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "true_hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "true_leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=15),
#   "true_leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=16),
#   "true_leakage_intensity_width_1": Float64Col(shape=(), dflt=0.0, pos=17),
#   "true_leakage_intensity_width_2": Float64Col(shape=(), dflt=0.0, pos=18),
#   "true_concentration_cog": Float64Col(shape=(), dflt=0.0, pos=19),
#   "true_concentration_core": Float64Col(shape=(), dflt=0.0, pos=20),
#   "true_concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=21),
#   "true_morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=22),
#   "true_morphology_n_islands": Int64Col(shape=(), dflt=0, pos=23),
#   "true_morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=24),
#   "true_morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=25),
#   "true_morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "true_intensity_max": Int32Col(shape=(), dflt=0, pos=27),
#   "true_intensity_min": Int32Col(shape=(), dflt=0, pos=28),
#   "true_intensity_mean": Float64Col(shape=(), dflt=0.0, pos=29),
#   "true_intensity_std": Float64Col(shape=(), dflt=0.0, pos=30),
#   "true_intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=31),
#   "true_intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=32)}
#   byteorder := 'little'
#   chunkshape := (266,)
# /simulation/event/telescope/parameters/tel_010 (Table(7570,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "true_hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "true_hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "true_hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "true_hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "true_hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "true_leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=15),
#   "true_leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=16),
#   "true_leakage_intensity_width_1": Float64Col(shape=(), dflt=0.0, pos=17),
#   "true_leakage_intensity_width_2": Float64Col(shape=(), dflt=0.0, pos=18),
#   "true_concentration_cog": Float64Col(shape=(), dflt=0.0, pos=19),
#   "true_concentration_core": Float64Col(shape=(), dflt=0.0, pos=20),
#   "true_concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=21),
#   "true_morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=22),
#   "true_morphology_n_islands": Int64Col(shape=(), dflt=0, pos=23),
#   "true_morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=24),
#   "true_morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=25),
#   "true_morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "true_intensity_max": Int32Col(shape=(), dflt=0, pos=27),
#   "true_intensity_min": Int32Col(shape=(), dflt=0, pos=28),
#   "true_intensity_mean": Float64Col(shape=(), dflt=0.0, pos=29),
#   "true_intensity_std": Float64Col(shape=(), dflt=0.0, pos=30),
#   "true_intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=31),
#   "true_intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=32)}
#   byteorder := 'little'
#   chunkshape := (266,)
# /simulation/event/telescope/parameters/tel_011 (Table(7437,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "true_hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "true_hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "true_hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "true_hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "true_hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "true_leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=15),
#   "true_leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=16),
#   "true_leakage_intensity_width_1": Float64Col(shape=(), dflt=0.0, pos=17),
#   "true_leakage_intensity_width_2": Float64Col(shape=(), dflt=0.0, pos=18),
#   "true_concentration_cog": Float64Col(shape=(), dflt=0.0, pos=19),
#   "true_concentration_core": Float64Col(shape=(), dflt=0.0, pos=20),
#   "true_concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=21),
#   "true_morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=22),
#   "true_morphology_n_islands": Int64Col(shape=(), dflt=0, pos=23),
#   "true_morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=24),
#   "true_morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=25),
#   "true_morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "true_intensity_max": Int32Col(shape=(), dflt=0, pos=27),
#   "true_intensity_min": Int32Col(shape=(), dflt=0, pos=28),
#   "true_intensity_mean": Float64Col(shape=(), dflt=0.0, pos=29),
#   "true_intensity_std": Float64Col(shape=(), dflt=0.0, pos=30),
#   "true_intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=31),
#   "true_intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=32)}
#   byteorder := 'little'
#   chunkshape := (266,)
# /simulation/event/telescope/parameters/tel_019 (Table(7680,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "true_hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "true_hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "true_hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "true_hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "true_hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "true_leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=15),
#   "true_leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=16),
#   "true_leakage_intensity_width_1": Float64Col(shape=(), dflt=0.0, pos=17),
#   "true_leakage_intensity_width_2": Float64Col(shape=(), dflt=0.0, pos=18),
#   "true_concentration_cog": Float64Col(shape=(), dflt=0.0, pos=19),
#   "true_concentration_core": Float64Col(shape=(), dflt=0.0, pos=20),
#   "true_concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=21),
#   "true_morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=22),
#   "true_morphology_n_islands": Int64Col(shape=(), dflt=0, pos=23),
#   "true_morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=24),
#   "true_morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=25),
#   "true_morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "true_intensity_max": Int32Col(shape=(), dflt=0, pos=27),
#   "true_intensity_min": Int32Col(shape=(), dflt=0, pos=28),
#   "true_intensity_mean": Float64Col(shape=(), dflt=0.0, pos=29),
#   "true_intensity_std": Float64Col(shape=(), dflt=0.0, pos=30),
#   "true_intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=31),
#   "true_intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=32)}
#   byteorder := 'little'
#   chunkshape := (266,)
# /simulation/event/telescope/parameters/tel_035 (Table(7639,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "true_hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "true_hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "true_hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "true_hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "true_hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "true_hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "true_hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "true_hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "true_hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "true_hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "true_hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "true_hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "true_leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=15),
#   "true_leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=16),
#   "true_leakage_intensity_width_1": Float64Col(shape=(), dflt=0.0, pos=17),
#   "true_leakage_intensity_width_2": Float64Col(shape=(), dflt=0.0, pos=18),
#   "true_concentration_cog": Float64Col(shape=(), dflt=0.0, pos=19),
#   "true_concentration_core": Float64Col(shape=(), dflt=0.0, pos=20),
#   "true_concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=21),
#   "true_morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=22),
#   "true_morphology_n_islands": Int64Col(shape=(), dflt=0, pos=23),
#   "true_morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=24),
#   "true_morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=25),
#   "true_morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "true_intensity_max": Int32Col(shape=(), dflt=0, pos=27),
#   "true_intensity_min": Int32Col(shape=(), dflt=0, pos=28),
#   "true_intensity_mean": Float64Col(shape=(), dflt=0.0, pos=29),
#   "true_intensity_std": Float64Col(shape=(), dflt=0.0, pos=30),
#   "true_intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=31),
#   "true_intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=32)}
#   byteorder := 'little'
#   chunkshape := (266,)
# /dl2/event (Group) ''
# /dl2/service (Group) ''
# /dl2/service/tel_event_statistics (Group) ''
# /dl2/service/tel_event_statistics/HillasReconstructor (Table(5,)fletcher32, shuffle, blosc:zstd(5)) ''
#   description := {
#   "criteria": StringCol(itemsize=16, shape=(), dflt=b'', pos=0),
#   "counts": Int64Col(shape=(), dflt=0, pos=1),
#   "cumulative_counts": Int64Col(shape=(), dflt=0, pos=2),
#   "func": StringCol(itemsize=42, shape=(), dflt=b'', pos=3)}
#   byteorder := 'little'
#   chunkshape := (885,)
# /dl2/event/subarray (Group) ''
# /dl2/event/telescope (Group) ''
# ...
#   "hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "timing_intercept": Float64Col(shape=(), dflt=0.0, pos=15),
#   "timing_deviation": Float64Col(shape=(), dflt=0.0, pos=16),
#   "timing_slope": Float64Col(shape=(), dflt=0.0, pos=17),
#   "leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=18),
#   "leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=19),
#   "leakage_intensity_width_1": Float32Col(shape=(), dflt=0.0, pos=20),
#   "leakage_intensity_width_2": Float32Col(shape=(), dflt=0.0, pos=21),
#   "concentration_cog": Float64Col(shape=(), dflt=0.0, pos=22),
#   "concentration_core": Float64Col(shape=(), dflt=0.0, pos=23),
#   "concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=24),
#   "morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=25),
#   "morphology_n_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=27),
#   "morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=28),
#   "morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=29),
#   "intensity_max": Float32Col(shape=(), dflt=0.0, pos=30),
#   "intensity_min": Float32Col(shape=(), dflt=0.0, pos=31),
#   "intensity_mean": Float32Col(shape=(), dflt=0.0, pos=32),
#   "intensity_std": Float32Col(shape=(), dflt=0.0, pos=33),
#   "intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=34),
#   "intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=35),
#   "peak_time_max": Float32Col(shape=(), dflt=0.0, pos=36),
#   "peak_time_min": Float32Col(shape=(), dflt=0.0, pos=37),
#   "peak_time_mean": Float32Col(shape=(), dflt=0.0, pos=38),
#   "peak_time_std": Float32Col(shape=(), dflt=0.0, pos=39),
#   "peak_time_skewness": Float64Col(shape=(), dflt=0.0, pos=40),
#   "peak_time_kurtosis": Float64Col(shape=(), dflt=0.0, pos=41),
#   "core_psi": Float64Col(shape=(), dflt=0.0, pos=42)}
#   byteorder := 'little'
#   chunkshape := (222,)
# /dl1/event/telescope/parameters/tel_011 (Table(7437,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,TimingParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer,PeakTimeStatisticsContainer,CoreParametersContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "timing_intercept": Float64Col(shape=(), dflt=0.0, pos=15),
#   "timing_deviation": Float64Col(shape=(), dflt=0.0, pos=16),
#   "timing_slope": Float64Col(shape=(), dflt=0.0, pos=17),
#   "leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=18),
#   "leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=19),
#   "leakage_intensity_width_1": Float32Col(shape=(), dflt=0.0, pos=20),
#   "leakage_intensity_width_2": Float32Col(shape=(), dflt=0.0, pos=21),
#   "concentration_cog": Float64Col(shape=(), dflt=0.0, pos=22),
#   "concentration_core": Float64Col(shape=(), dflt=0.0, pos=23),
#   "concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=24),
#   "morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=25),
#   "morphology_n_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=27),
#   "morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=28),
#   "morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=29),
#   "intensity_max": Float32Col(shape=(), dflt=0.0, pos=30),
#   "intensity_min": Float32Col(shape=(), dflt=0.0, pos=31),
#   "intensity_mean": Float32Col(shape=(), dflt=0.0, pos=32),
#   "intensity_std": Float32Col(shape=(), dflt=0.0, pos=33),
#   "intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=34),
#   "intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=35),
#   "peak_time_max": Float32Col(shape=(), dflt=0.0, pos=36),
#   "peak_time_min": Float32Col(shape=(), dflt=0.0, pos=37),
#   "peak_time_mean": Float32Col(shape=(), dflt=0.0, pos=38),
#   "peak_time_std": Float32Col(shape=(), dflt=0.0, pos=39),
#   "peak_time_skewness": Float64Col(shape=(), dflt=0.0, pos=40),
#   "peak_time_kurtosis": Float64Col(shape=(), dflt=0.0, pos=41),
#   "core_psi": Float64Col(shape=(), dflt=0.0, pos=42)}
#   byteorder := 'little'
#   chunkshape := (222,)
# /dl1/event/telescope/parameters/tel_019 (Table(7680,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,TimingParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer,PeakTimeStatisticsContainer,CoreParametersContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "timing_intercept": Float64Col(shape=(), dflt=0.0, pos=15),
#   "timing_deviation": Float64Col(shape=(), dflt=0.0, pos=16),
#   "timing_slope": Float64Col(shape=(), dflt=0.0, pos=17),
#   "leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=18),
#   "leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=19),
#   "leakage_intensity_width_1": Float32Col(shape=(), dflt=0.0, pos=20),
#   "leakage_intensity_width_2": Float32Col(shape=(), dflt=0.0, pos=21),
#   "concentration_cog": Float64Col(shape=(), dflt=0.0, pos=22),
#   "concentration_core": Float64Col(shape=(), dflt=0.0, pos=23),
#   "concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=24),
#   "morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=25),
#   "morphology_n_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=27),
#   "morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=28),
#   "morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=29),
#   "intensity_max": Float32Col(shape=(), dflt=0.0, pos=30),
#   "intensity_min": Float32Col(shape=(), dflt=0.0, pos=31),
#   "intensity_mean": Float32Col(shape=(), dflt=0.0, pos=32),
#   "intensity_std": Float32Col(shape=(), dflt=0.0, pos=33),
#   "intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=34),
#   "intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=35),
#   "peak_time_max": Float32Col(shape=(), dflt=0.0, pos=36),
#   "peak_time_min": Float32Col(shape=(), dflt=0.0, pos=37),
#   "peak_time_mean": Float32Col(shape=(), dflt=0.0, pos=38),
#   "peak_time_std": Float32Col(shape=(), dflt=0.0, pos=39),
#   "peak_time_skewness": Float64Col(shape=(), dflt=0.0, pos=40),
#   "peak_time_kurtosis": Float64Col(shape=(), dflt=0.0, pos=41),
#   "core_psi": Float64Col(shape=(), dflt=0.0, pos=42)}
#   byteorder := 'little'
#   chunkshape := (222,)
# /dl1/event/telescope/parameters/tel_035 (Table(7639,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,HillasParametersContainer,TimingParametersContainer,LeakageContainer,ConcentrationContainer,MorphologyContainer,IntensityStatisticsContainer,PeakTimeStatisticsContainer,CoreParametersContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "event_id": Int64Col(shape=(), dflt=0, pos=1),
#   "tel_id": Int16Col(shape=(), dflt=0, pos=2),
#   "hillas_intensity": Float64Col(shape=(), dflt=0.0, pos=3),
#   "hillas_skewness": Float64Col(shape=(), dflt=0.0, pos=4),
#   "hillas_kurtosis": Float64Col(shape=(), dflt=0.0, pos=5),
#   "hillas_fov_lon": Float64Col(shape=(), dflt=0.0, pos=6),
#   "hillas_fov_lat": Float64Col(shape=(), dflt=0.0, pos=7),
#   "hillas_r": Float64Col(shape=(), dflt=0.0, pos=8),
#   "hillas_phi": Float64Col(shape=(), dflt=0.0, pos=9),
#   "hillas_length": Float64Col(shape=(), dflt=0.0, pos=10),
#   "hillas_length_uncertainty": Float64Col(shape=(), dflt=0.0, pos=11),
#   "hillas_width": Float64Col(shape=(), dflt=0.0, pos=12),
#   "hillas_width_uncertainty": Float64Col(shape=(), dflt=0.0, pos=13),
#   "hillas_psi": Float64Col(shape=(), dflt=0.0, pos=14),
#   "timing_intercept": Float64Col(shape=(), dflt=0.0, pos=15),
#   "timing_deviation": Float64Col(shape=(), dflt=0.0, pos=16),
#   "timing_slope": Float64Col(shape=(), dflt=0.0, pos=17),
#   "leakage_pixels_width_1": Float64Col(shape=(), dflt=0.0, pos=18),
#   "leakage_pixels_width_2": Float64Col(shape=(), dflt=0.0, pos=19),
#   "leakage_intensity_width_1": Float32Col(shape=(), dflt=0.0, pos=20),
#   "leakage_intensity_width_2": Float32Col(shape=(), dflt=0.0, pos=21),
#   "concentration_cog": Float64Col(shape=(), dflt=0.0, pos=22),
#   "concentration_core": Float64Col(shape=(), dflt=0.0, pos=23),
#   "concentration_pixel": Float64Col(shape=(), dflt=0.0, pos=24),
#   "morphology_n_pixels": Int64Col(shape=(), dflt=0, pos=25),
#   "morphology_n_islands": Int64Col(shape=(), dflt=0, pos=26),
#   "morphology_n_small_islands": Int64Col(shape=(), dflt=0, pos=27),
#   "morphology_n_medium_islands": Int64Col(shape=(), dflt=0, pos=28),
#   "morphology_n_large_islands": Int64Col(shape=(), dflt=0, pos=29),
#   "intensity_max": Float32Col(shape=(), dflt=0.0, pos=30),
#   "intensity_min": Float32Col(shape=(), dflt=0.0, pos=31),
#   "intensity_mean": Float32Col(shape=(), dflt=0.0, pos=32),
#   "intensity_std": Float32Col(shape=(), dflt=0.0, pos=33),
#   "intensity_skewness": Float64Col(shape=(), dflt=0.0, pos=34),
#   "intensity_kurtosis": Float64Col(shape=(), dflt=0.0, pos=35),
#   "peak_time_max": Float32Col(shape=(), dflt=0.0, pos=36),
#   "peak_time_min": Float32Col(shape=(), dflt=0.0, pos=37),
#   "peak_time_mean": Float32Col(shape=(), dflt=0.0, pos=38),
#   "peak_time_std": Float32Col(shape=(), dflt=0.0, pos=39),
#   "peak_time_skewness": Float64Col(shape=(), dflt=0.0, pos=40),
#   "peak_time_kurtosis": Float64Col(shape=(), dflt=0.0, pos=41),
#   "core_psi": Float64Col(shape=(), dflt=0.0, pos=42)}
#   byteorder := 'little'
#   chunkshape := (222,)
# /configuration/instrument (Group) ''
# /configuration/observation (Group) ''
# /configuration/observation/observation_block (Table(50,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of ObservationBlockContainer'
#   description := {
#   "obs_id": UInt64Col(shape=(), dflt=0, pos=0),
#   "sb_id": UInt64Col(shape=(), dflt=0, pos=1),
#   "producer_id": StringCol(itemsize=10, shape=(), dflt=b'', pos=2),
#   "state": Int64Col(shape=(), dflt=0, pos=3),
#   "subarray_pointing_lat": Float64Col(shape=(), dflt=0.0, pos=4),
#   "subarray_pointing_lon": Float64Col(shape=(), dflt=0.0, pos=5),
#   "subarray_pointing_frame": Int64Col(shape=(), dflt=0, pos=6),
#   "scheduled_duration": Float64Col(shape=(), dflt=0.0, pos=7),
#   "scheduled_start_time": Float64Col(shape=(), dflt=0.0, pos=8),
#   "actual_start_time": Float64Col(shape=(), dflt=0.0, pos=9),
#   "actual_duration": Float64Col(shape=(), dflt=0.0, pos=10)}
#   byteorder := 'little'
#   chunkshape := (728,)
# /configuration/observation/scheduling_block (Table(50,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of SchedulingBlockContainer'
#   description := {
#   "sb_id": UInt64Col(shape=(), dflt=0, pos=0),
#   "sb_type": Int64Col(shape=(), dflt=0, pos=1),
#   "producer_id": StringCol(itemsize=10, shape=(), dflt=b'', pos=2),
#   "observing_mode": Int64Col(shape=(), dflt=0, pos=3),
#   "pointing_mode": Int64Col(shape=(), dflt=0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (1560,)
# /configuration/simulation (Group) ''
# /configuration/simulation/run (Table(50,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of ExtraSimInfo,SimulationConfigContainer'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "corsika_version": Int64Col(shape=(), dflt=0, pos=1),
#   "simtel_version": Int64Col(shape=(), dflt=0, pos=2),
#   "energy_range_min": Float32Col(shape=(), dflt=0.0, pos=3),
#   "energy_range_max": Float32Col(shape=(), dflt=0.0, pos=4),
#   "prod_site_B_total": Float64Col(shape=(), dflt=0.0, pos=5),
#   "prod_site_B_declination": Float64Col(shape=(), dflt=0.0, pos=6),
#   "prod_site_B_inclination": Float64Col(shape=(), dflt=0.0, pos=7),
#   "prod_site_alt": Float64Col(shape=(), dflt=0.0, pos=8),
#   "spectral_index": Float64Col(shape=(), dflt=0.0, pos=9),
#   "shower_prog_start": Int64Col(shape=(), dflt=0, pos=10),
#   "shower_prog_id": Int64Col(shape=(), dflt=0, pos=11),
#   "detector_prog_start": Int64Col(shape=(), dflt=0, pos=12),
#   "detector_prog_id": Int64Col(shape=(), dflt=0, pos=13),
#   "n_showers": Int64Col(shape=(), dflt=0, pos=14),
#   "shower_reuse": Int64Col(shape=(), dflt=0, pos=15),
#   "max_alt": Float32Col(shape=(), dflt=0.0, pos=16),
#   "min_alt": Float32Col(shape=(), dflt=0.0, pos=17),
#   "max_az": Float32Col(shape=(), dflt=0.0, pos=18),
#   "min_az": Float32Col(shape=(), dflt=0.0, pos=19),
#   "diffuse": Int64Col(shape=(), dflt=0, pos=20),
#   "max_viewcone_radius": Float32Col(shape=(), dflt=0.0, pos=21),
#   "min_viewcone_radius": Float32Col(shape=(), dflt=0.0, pos=22),
#   "max_scatter_range": Float32Col(shape=(), dflt=0.0, pos=23),
#   "min_scatter_range": Float32Col(shape=(), dflt=0.0, pos=24),
#   "core_pos_mode": Int64Col(shape=(), dflt=0, pos=25),
#   "injection_height": Float64Col(shape=(), dflt=0.0, pos=26),
#   "atmosphere": Int64Col(shape=(), dflt=0, pos=27),
#   "corsika_iact_options": Int64Col(shape=(), dflt=0, pos=28),
#   "corsika_low_E_model": Int64Col(shape=(), dflt=0, pos=29),
#   "corsika_high_E_model": Int64Col(shape=(), dflt=0, pos=30),
#   "corsika_bunchsize": Float64Col(shape=(), dflt=0.0, pos=31),
#   "corsika_wlen_min": Float64Col(shape=(), dflt=0.0, pos=32),
#   "corsika_wlen_max": Float64Col(shape=(), dflt=0.0, pos=33),
#   "corsika_low_E_detail": Int64Col(shape=(), dflt=0, pos=34),
#   "corsika_high_E_detail": Int64Col(shape=(), dflt=0, pos=35)}
#   byteorder := 'little'
#   chunkshape := (268,)
# /configuration/instrument/subarray (Group) ''
# /configuration/instrument/subarray/layout (Table(13,)fletcher32, shuffle, blosc:zstd(5)) ''
#   description := {
#   "tel_id": Int16Col(shape=(), dflt=0, pos=0),
#   "name": StringCol(itemsize=3, shape=(), dflt=b'', pos=1),
#   "type": StringCol(itemsize=3, shape=(), dflt=b'', pos=2),
#   "pos_x": Float32Col(shape=(), dflt=0.0, pos=3),
#   "pos_y": Float32Col(shape=(), dflt=0.0, pos=4),
#   "pos_z": Float32Col(shape=(), dflt=0.0, pos=5),
#   "camera_name": StringCol(itemsize=9, shape=(), dflt=b'', pos=6),
#   "optics_name": StringCol(itemsize=3, shape=(), dflt=b'', pos=7),
#   "camera_index": Int64Col(shape=(), dflt=0, pos=8),
#   "optics_index": Int64Col(shape=(), dflt=0, pos=9),
#   "tel_description": StringCol(itemsize=17, shape=(), dflt=b'', pos=10)}
#   byteorder := 'little'
#   chunkshape := (1008,)
# /configuration/instrument/telescope (Group) ''
# >
